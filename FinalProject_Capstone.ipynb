# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
# !pip install --upgrade openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\suele\anaconda4\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\suele\anaconda4\lib\site-packages (from openpyxl) (1.1.0)
